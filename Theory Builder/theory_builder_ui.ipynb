# %%
from theory_builder import Theory, TheoryUI

ui = TheoryUI()

# %%
ui.show()

# %%
# --- After filling in the UI above, inspect / save the theory ---
theory = ui.theory
print(theory.summary())

# Save:
# theory.save('theories/my_theory.yaml')

# Reload:
# theory = Theory.load('theories/my_theory.yaml')

# Access SymPy objects directly:
# S_int = theory.get_interacting_action()
# G = theory.get_propagator(0, 0)
# Out:
# Theory     :
# Descr      :
# Stationary : True
# Fields     : []  →  []
# Params     : []
#
# Propagator matrix:
#
# Vertices  (mode: manual):
#   (none)
